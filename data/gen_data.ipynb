# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %%
benign = pd.read_csv("benign.csv")
malicious = pd.read_csv("malicious.csv")

# %%
benign["domain_type"] = "benign"
benign = benign.sample(10000)

# %%
malicious["domain_type"] = "dga"
malicious = malicious.sample(10000)

# %%
data = [benign, malicious]
data = pd.concat(data)
data = shuffle(data)
data = data.reset_index(drop=True)
data
# Out:
#                           domain domain_type
# 0           wisuolycossttqrj.com         dga
# 1                   wi-wamss.org      benign
# 2           qcxfurnkbqidxxcl.biz         dga
# 3           192-168-1-1-admin.ru      benign
# 4            dblsiobnkjxomkmh.ru         dga
# ...                          ...         ...
# 19995         delanceystreet.com      benign
# 19996  tulun1aklass.blogspot.com      benign
# 19997              pollaminat.ru      benign
# 19998       sgbjolycossttqrj.net         dga
# 19999       abreuelima.pe.gov.br      benign
#
# [20000 rows x 2 columns]

# %%
data.to_csv('initial_data.csv',index=False)

# %%
pd.read_csv('initial_data.csv')
# Out:
#                           domain domain_type
# 0           wisuolycossttqrj.com         dga
# 1                   wi-wamss.org      benign
# 2           qcxfurnkbqidxxcl.biz         dga
# 3           192-168-1-1-admin.ru      benign
# 4            dblsiobnkjxomkmh.ru         dga
# ...                          ...         ...
# 19995         delanceystreet.com      benign
# 19996  tulun1aklass.blogspot.com      benign
# 19997              pollaminat.ru      benign
# 19998       sgbjolycossttqrj.net         dga
# 19999       abreuelima.pe.gov.br      benign
#
# [20000 rows x 2 columns]
